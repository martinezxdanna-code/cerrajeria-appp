# %%
{
  "name": "Cerrajería",
  "short_name": "Cerrajería",
  "start_url": "cerrajeria.html",
  "display": "standalone",
  "background_color": "#ffffff",
  "theme_color": "#333333",
  "icons": [
    {
      "src": "icon.png",
      "sizes": "192x192",
      "type": "image/png"
    }
  ]
}
# Out:
# {'name': 'Cerrajería',
#  'short_name': 'Cerrajería',
#  'start_url': 'cerrajeria.html',
#  'display': 'standalone',
#  'background_color': '#ffffff',
#  'theme_color': '#333333',
#  'icons': [{'src': 'icon.png', 'sizes': '192x192', 'type': 'image/png'}]}
